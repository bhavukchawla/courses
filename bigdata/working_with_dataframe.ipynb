# %% [markdown]
# ### Step 1: Create the dataframe from userdetails.json file

# %%
df = spark.read.json("/user/datacouch21/data/userdetails.json")
df.show(truncate=False)
# Out:
# +------------------------+----------------------------+----------+------+---+---------------+---------+---------------+----------+
# |city                    |email                       |first_name|gender|id |ip_address     |last_name|race           |timestamp |
# +------------------------+----------------------------+----------+------+---+---------------+---------+---------------+----------+
# |Miami                   |wbell0@tumblr.com           |Wayne     |Male  |1  |77.152.229.131 |Bell     |Costa Rican    |1463468947|
# |Xiejia                  |aallen1@state.gov           |Anthony   |Male  |2  |62.49.195.170  |Allen    |Comanche       |1447538277|
# |Illintsi                |ehenderson2@theguardian.com |Eric      |Male  |3  |136.129.71.231 |Henderson|Comanche       |1476462811|
# |Tugusirna               |jsmith3@spiegel.de          |Jimmy     |Male  |4  |117.176.172.187|Smith    |Native Hawaiian|1445804900|
# |Nasīrābād               |dwheeler4@vkontakte.ru      |Diana     |Female|5  |119.222.120.140|Wheeler  |Lumbee         |1460377451|
# |Pousada                 |khall5@pbs.org              |Karen     |Female|6  |9.111.177.81   |Hall     |Polynesian     |1450344798|
# |Évreux                  |prodriguez6@wsj.com         |Philip    |Male  |7  |202.53.81.233  |Rodriguez|Malaysian      |1459998561|
# |Vihāri                  |abryant7@com.com            |Ashley    |Female|8  |163.245.127.162|Bryant   |Lumbee         |1445570397|
# |Magnitka                |ngrant8@nasa.gov            |Norma     |Female|9  |43.133.191.129 |Grant    |Sri Lankan     |1462939469|
# |Keffi                   |hlewis9@ucsd.edu            |Helen     |Female|10 |74.149.202.229 |Lewis    |Salvadoran     |1474416280|
# |Волочаевское            |lmccoya@jiathis.com         |Larry     |Male  |11 |36.136.37.15   |Mccoy    |Venezuelan     |1474672688|
# |Madison                 |ewoodb@youtube.com          |Emily     |Female|12 |7.239.252.142  |Wood     |Peruvian       |1478199845|
# |Cicheng                 |palvarezc@delicious.com     |Patrick   |Male  |13 |184.86.19.219  |Alvarez  |Yuman          |1443691208|
# |Xiaomenjia              |ebowmand@usnews.com         |Eugene    |Male  |14 |173.159.51.207 |Bowman   |Chickasaw      |1452109688|
# |Boaco                   |pwrighte@furl.net           |Phyllis   |Female|15 |159.165.133.224|Wright   |Puerto Rican   |1441154207|
# |Iturama                 |rrosef@cmu.edu              |Roy       |Male  |16 |52.205.107.86  |Rose     |Pakistani      |1463401327|
# |Tochigi                 |ahunterg@acquirethisname.com|Albert    |Male  |17 |21.237.126.164 |Hunter   |Costa Rican    |1457692077|
# |Petite Rivière de Nippes|ahowardh@guardian.co.uk     |Antonio   |Male  |18 |111.107.201.180|Howard   |Pakistani      |1444392400|
# |Zaliznychne             |rstonei@macromedia.com      |Robert    |Male  |19 |189.196.30.146 |Stone    |Ottawa         |1458466303|
# |Sukahening              |dcrawfordj@netscape.com     |Dorothy   |Female|20 |146.5.243.193  |Crawford |Menominee      |1463590952|
# +------------------------+----------------------------+----------+------+---+---------------+---------+---------------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Step 2: Print the schema in a  tree format.

# %%
df.printSchema()
# Out:
# root
#  |-- city: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- ip_address: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- race: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %% [markdown]
# ### Step 3: Select only the first_name column.

# %%
df.select("first_name").show()
# Out:
# +----------+
# |first_name|
# +----------+
# |     Wayne|
# |   Anthony|
# |      Eric|
# |     Jimmy|
# |     Diana|
# |     Karen|
# |    Philip|
# |    Ashley|
# |     Norma|
# |     Helen|
# |     Larry|
# |     Emily|
# |   Patrick|
# |    Eugene|
# |   Phyllis|
# |       Roy|
# |    Albert|
# |   Antonio|
# |    Robert|
# |   Dorothy|
# +----------+
# only showing top 20 rows

# %% [markdown]
# ### Step 4: Count the number of people by gender.

# %%
df.groupBy("gender").count().show()
# Out:
# +------+-----+
# |gender|count|
# +------+-----+
# |Female|  507|
# |  Male|  493|
# +------+-----+

# %% [markdown]
# ### Step 5: Select the  people whose id is greater than 30.

# %%
details=df.filter(df['id'] > 30)

# %%
details.show()
# Out:
# +--------------------+--------------------+----------+------+---+---------------+---------+--------------------+----------+
# |                city|               email|first_name|gender| id|     ip_address|last_name|                race| timestamp|
# +--------------------+--------------------+----------+------+---+---------------+---------+--------------------+----------+
# |           Sembakung|wleeu@chronoengin...|     Wanda|Female| 31|  155.210.60.27|      Lee|              Korean|1459621486|
# |        Karanggeneng|   brayv@example.com|    Bonnie|Female| 32|195.232.235.145|      Ray|            Delaware|1436824502|
# |              Baiyan|aaustinw@chicagot...|    Angela|Female| 33|142.235.215.210|   Austin|           Cambodian|1474366455|
# |              Plavsk|    ageorgex@hhs.gov|       Amy|Female| 34|  60.112.106.36|   George|            Seminole|1446059690|
# |            Plumtree|    ideany@salon.com|     Irene|Female| 35|  150.69.30.179|     Dean|              Pueblo|1458412193|
# |           Barinitas| klynchz@4shared.com|  Kimberly|Female| 36| 47.198.228.160|    Lynch|     Native Hawaiian|1477826863|
# |               Uthai|   jmedina10@icio.us|      Jane|Female| 37|   101.35.64.93|   Medina|Native Hawaiian a...|1445940255|
# |              Suchań|  mjenkins11@last.fm|   Matthew|  Male| 38|  4.243.194.186|  Jenkins|              Paiute|1478116071|
# |             Triolet|pbutler12@blogtal...|    Pamela|Female| 39|     73.90.6.34|   Butler|              Korean|1448070262|
# |                Mesa|hburton13@bandcam...|     Harry|  Male| 40|  43.210.10.124|   Burton|               Yuman|1452745031|
# |              Mizque|   jbailey14@wix.com|     Jason|  Male| 41|  45.206.210.65|   Bailey|            Chamorro|1476197028|
# |         Santa Tecla|    lward15@lulu.com|      Lois|Female| 42| 52.181.192.140|     Ward|         Micronesian|1468988218|
# |           Nalinggou|rkennedy16@dion.n...|      Rose|Female| 43|  166.5.223.108|  Kennedy|           Chickasaw|1477476167|
# |               Baixi|jcoleman17@t-onli...|  Jennifer|Female| 44| 145.218.132.69|  Coleman|          Melanesian|1446281262|
# |Nossa Senhora do ...|hparker18@squares...|     Helen|Female| 45|  169.195.62.85|   Parker|              Korean|1451975695|
# |            Lefkímmi|     kross19@gnu.org|  Kathleen|Female| 46|  213.22.180.50|     Ross|            Bolivian|1459647708|
# |           Koungheul|jbaker1a@arstechn...|    Joseph|  Male| 47|   124.90.97.18|    Baker|               Yaqui|1476124407|
# |         Kampungdesa|   cwebb1b@prweb.com| Christina|Female| 48|   32.82.211.76|     Webb|            Colville|1477341408|
# |               Miami|pmarshall1c@chron...|   Phillip|  Male| 49|   35.192.8.217| Marshall|           Malaysian|1461391158|
# |           Kimberley|  lhenry1d@wired.com|   Lillian|Female| 50|  48.252.51.186|    Henry|          Indonesian|1474510830|
# +--------------------+--------------------+----------+------+---+---------------+---------+--------------------+----------+
# only showing top 20 rows

# %%
details.write.mode("overwrite").csv('/user/datacouch21/persons_details')

# %%
# !hdfs dfs -ls /user/datacouch21/persons_details
# Out:
# Found 2 items
# -rw-r--r--   1 root hadoop          0 2020-04-26 08:33 /user/datacouch21/persons_details/_SUCCESS
# -rw-r--r--   1 root hadoop      88888 2020-04-26 08:33 /user/datacouch21/persons_details/part-00000-5d9f30f6-dd0f-4c63-a0f8-97f4f3de2ac7-c000.csv

# %%
# !hdfs dfs -cat /user/datacouch21/persons_details/part-* | head
# Out:
# Sembakung,wleeu@chronoengine.com,Wanda,Female,31,155.210.60.27,Lee,Korean,1459621486
# Karanggeneng,brayv@example.com,Bonnie,Female,32,195.232.235.145,Ray,Delaware,1436824502
# Baiyan,aaustinw@chicagotribune.com,Angela,Female,33,142.235.215.210,Austin,Cambodian,1474366455
# Plavsk,ageorgex@hhs.gov,Amy,Female,34,60.112.106.36,George,Seminole,1446059690
# Plumtree,ideany@salon.com,Irene,Female,35,150.69.30.179,Dean,Pueblo,1458412193
# Barinitas,klynchz@4shared.com,Kimberly,Female,36,47.198.228.160,Lynch,Native Hawaiian,1477826863
# Uthai,jmedina10@icio.us,Jane,Female,37,101.35.64.93,Medina,Native Hawaiian and Other Pacific Islander (NHPI),1445940255
# Suchań,mjenkins11@last.fm,Matthew,Male,38,4.243.194.186,Jenkins,Paiute,1478116071
# Triolet,pbutler12@blogtalkradio.com,Pamela,Female,39,73.90.6.34,Butler,Korean,1448070262
# Mesa,hburton13@bandcamp.com,Harry,Male,40,43.210.10.124,Burton,Yuman,1452745031
# cat: Unable to write to output stream.

# %% [markdown]
# ### END
